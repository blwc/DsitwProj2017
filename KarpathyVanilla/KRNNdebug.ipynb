# %%
import numpy as np

# data I/O
data = open('tinyshakes.txt', 'r').read() # should be simple plain text file
chars = list(set(data))
data_size, vocab_size = len(data), len(chars)
print('data has %d characters, %d unique.' % (data_size, vocab_size))
char_to_ix = { ch:i for i,ch in enumerate(chars) }
ix_to_char = { i:ch for i,ch in enumerate(chars) }

# hyperparameters
hidden_size = 100 # size of hidden layer of neurons
seq_length = 25 # number of steps to unroll the RNN for
learning_rate = 1e-1

# model parameters
Wxh = np.random.randn(hidden_size, vocab_size)*0.01 # input to hidden
Whh = np.random.randn(hidden_size, hidden_size)*0.01 # hidden to hidden
Why = np.random.randn(vocab_size, hidden_size)*0.01 # hidden to output
bh = np.zeros((hidden_size, 1)) # hidden bias
by = np.zeros((vocab_size, 1)) # output bias
# Out:
# data has 1115390 characters, 65 unique.

# %%
def lossFun(inputs, targets, hprev):
  """
  inputs,targets are both list of integers.
  hprev is Hx1 array of initial hidden state
  returns the loss, gradients on model parameters, and last hidden state
  """
  xs, hs, ys, ps = {}, {}, {}, {}
  hs[-1] = np.copy(hprev)
  loss = 0
  # forward pass
  for t in range(len(inputs)):
    xs[t] = np.zeros((vocab_size,1)) # encode in 1-of-k representation
    xs[t][inputs[t]] = 1
    hs[t] = np.tanh(np.dot(Wxh, xs[t]) + np.dot(Whh, hs[t-1]) + bh) # hidden state
    ys[t] = np.dot(Why, hs[t]) + by # unnormalized log probabilities for next chars
    ps[t] = np.exp(ys[t]) / np.sum(np.exp(ys[t])) # probabilities for next chars
    loss += -np.log(ps[t][targets[t],0]) # softmax (cross-entropy loss)
  # backward pass: compute gradients going backwards
  dWxh, dWhh, dWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
  dbh, dby = np.zeros_like(bh), np.zeros_like(by)
  dhnext = np.zeros_like(hs[0])
  for t in reversed(range(len(inputs))):
    dy = np.copy(ps[t])
    dy[targets[t]] -= 1 # backprop into y. see http://cs231n.github.io/neural-networks-case-study/#grad if confused here
    dWhy += np.dot(dy, hs[t].T)
    dby += dy
    dh = np.dot(Why.T, dy) + dhnext # backprop into h
    dhraw = (1 - hs[t] * hs[t]) * dh # backprop through tanh nonlinearity
    dbh += dhraw
    dWxh += np.dot(dhraw, xs[t].T)
    dWhh += np.dot(dhraw, hs[t-1].T)
    dhnext = np.dot(Whh.T, dhraw)
  for dparam in [dWxh, dWhh, dWhy, dbh, dby]:
    np.clip(dparam, -5, 5, out=dparam) # clip to mitigate exploding gradients
  return loss, dWxh, dWhh, dWhy, dbh, dby, hs[len(inputs)-1]

# %%
def sample(h, seed_ix, n):
  """
  sample a sequence of integers from the model
  h is memory state, seed_ix is seed letter for first time step
  """
  x = np.zeros((vocab_size, 1))
  x[seed_ix] = 1
  ixes = []
  for t in range(n):
    h = np.tanh(np.dot(Wxh, x) + np.dot(Whh, h) + bh)
    y = np.dot(Why, h) + by
    p = np.exp(y) / np.sum(np.exp(y))
    ix = np.random.choice(range(vocab_size), p=p.ravel())
    x = np.zeros((vocab_size, 1))
    x[ix] = 1
    ixes.append(ix)
  return ixes

# %%
n, p = 0, 0
mWxh, mWhh, mWhy = np.zeros_like(Wxh), np.zeros_like(Whh), np.zeros_like(Why)
mbh, mby = np.zeros_like(bh), np.zeros_like(by) # memory variables for Adagrad
smooth_loss = -np.log(1.0/vocab_size)*seq_length # loss at iteration 0

# %%
while True:
  # prepare inputs (we're sweeping from left to right in steps seq_length long)
  if p+seq_length+1 >= len(data) or n == 0:
    hprev = np.zeros((hidden_size,1)) # reset RNN memory
    p = 0 # go from start of data
  inputs = [char_to_ix[ch] for ch in data[p:p+seq_length]]
  targets = [char_to_ix[ch] for ch in data[p+1:p+seq_length+1]]

  # sample from the model now and then
  if n % 100 == 0:
    sample_ix = sample(hprev, inputs[0], 200)
    txt = ''.join(ix_to_char[ix] for ix in sample_ix)
    print( '----\n %s \n----' % (txt, ) )

  # forward seq_length characters through the net and fetch gradient
  loss, dWxh, dWhh, dWhy, dbh, dby, hprev = lossFun(inputs, targets, hprev)
  smooth_loss = smooth_loss * 0.999 + loss * 0.001
  if n % 100 == 0: print( 'iter %d, loss: %f' % (n, smooth_loss) ) # print progress 

  # perform parameter update with Adagrad
  for param, dparam, mem in zip([Wxh, Whh, Why, bh, by], [dWxh, dWhh, dWhy, dbh, dby], [mWxh, mWhh, mWhy, mbh, mby]):
      mem += dparam * dparam
      param += -learning_rate * dparam / np.sqrt(mem + 1e-8) # adagrad update

  p += seq_length # move data pointer
  n += 1 # iteration counter
# Out:
# ----
#  y prit! hamonver?
#
# MENTZCARS OFiend;
# Andanst gur canting.
# 'R Nendon'd vill miod
# What
# Rkeats, hamegs,
# Werat sull heark, shosgenws the prifeie, and me thy dinfery, a bo him ham may,--
# Rusk lincower lung
# ----
# iter 65600, loss: 49.458548
# ----
#  ngesh'd na Right? stapw pord it se?
#
# ROMEO:
# O, But-magen his venor out,
# Latk tougl the and lear
# Plet's, wertiet;
# Shein, of in me bumping comble he my heem sortiin; promse your sers oxt ppammy will tha
# ----
# iter 65700, loss: 49.280545
# ----
#  ther: thy loy?
#
# MRIET:
# To my arumsatall thele,
# The way truot.
#
# ROMEO:
# Whot to shour, of grould phouldd, ore, be, temone'd. Fole been, are in foo.
# Whes!
#
# JUMELAS:
# Ton?
# By feod gham, to thich so lidiled
# ----
# iter 65800, loss: 49.358700
# ----
#  iths dook,
# Orn in in istwell my thall not mast of itimy:
# Whec' stimlt hack am Singerd, be I co dodfor prichort, thougrs mank, out on this the his cluit thatr hock goule liok.
#
# RICHO:
# Whe gothut and ti
# ----
# iter 65900, loss: 49.114258
# ----
#  n for shoppon warmoy youl ath:
# Tho pruit thy upeanio's cin he
# In to my shead,
# You so.
#
# LENCETVINGO:
# You not now of a siladnold.
#
# JULIET:
# Whe-'gaing mank of gofling, lidedears ofe lomk me fay not dith
# ----
# iter 66000, loss: 48.889128
# ----
#  go,
# Ryouchceat shamus bath thablire, in me thou lint lay,
# Dayes: of leing mught!
# Depent, I but depase, thish loy in thee;
# Were.'
# Thl acc'ut have; nanarden the ene, werth, the herser-drokes sish' ligh
# ----
# iter 66100, loss: 48.976754
# ----
#  r them hamg.
# Un lid bee me as may Eite dengald, would'd yey nay.
# 't to my for, and me linpers hamen, whous senteven Jurtirf
# Ald thit to a me that shames makesesch that, as noud twelcind dount in have.
# ----
# iter 66200, loss: 48.893783
# ----
#   bust deacrule.
#
# JURENCE:
# Thou locterte shaceh, shou hime be.
#
# JULETquace:
# If with me waquelines, frirting, the hanst that larrs leate thee is led ghand more weren to! Sigh noe my drostoul chior, and
# ----
# iter 66300, loss: 48.540164
# ----
#   koue to my co corn, tine what fattoonitst not mak: castie, hanbour un and I fall Omad, year
# Marrgemanalie;
# For cont thou!
# Stom that someine of ad:
#
# DULEO:
# I my not in on hou the ganden comg!
# To you m
# ----
# iter 66400, loss: 48.545033
# ----
#   not leak? Edrercly?
# Wildim heeters;
# So apeacsierds 'ant your entler;
# Chich then deakrot no way bool our pustaliy come.
#
# JULIET:
# Rullionss sun emon hive difgen
# Will ust thet to you deaksurle and teavo
# ----
# iter 66500, loss: 48.444447
# ----
#  n were:
# I'll the po toall yealise with thou son I seen:
# Of wher, my burle dead Dontroricraxt.
#
# ARUME LUNEL:
# Same Cood heep sisimbly do the chake? I will whatul.
# Seea.
#
# IRKIO:
# Cas I
# are,
# Thill wack.
#
# N
# ----
# iter 66600, loss: 48.405061
# ----
#   ben's on?
# In bet; it this I woth took gink! ghall wey the cill ledr wnicking hayteld ind if And dith werr of a yeales unce made.
# 't age
# Mynt nedy that, atuy,
# I it ther!
# And sod, I all, pray bur I dor
# ----
# iter 66700, loss: 48.526267
# ----
#   is welict that love ank aive un ther.
#
# FRLLOM:
# Makmin? 'il a fasham oft.
#
# FRADiHARDENY:
# I, will!
#
# PADETS:
# Bbaud dnow ares, insead, fauth appee, exte: take.
#
# MARIANCE:
# For it true's thous dur mores'd
# ----
# iter 66800, loss: 48.593937
# ----
#  ngse:
# yous onse.
#
# CAPELLOPEL:
# Will shut I, me moath shear, with menglor elick me Swerre:
# Sucper arriyen to it and in to as sarimed her sit os, mighter your all congun your nows, nor upaght, makan oun,
# ----
# iter 66900, loss: 48.850419
# ----
#   jile.
#
# Furbyien!
# And floth is -arryiothous ghall offellalld faltiech gingerd, bash then
# Aren.
#
# FRrCOR:
# Thou spaid, if erate!.
# O, very,
# The swome ane thoust is chathtrer doy lish monst, me.
#
# Noks deer
# ----
# iter 67000, loss: 49.092104
# ----
#  y and me come!
# Not to thing that me ho: notions nut brit truep shild rowny fulle shallby cover-asshild!
#
# PETCANS:
# Nit
# Till guver.
#
# Plceblo; I houct'd and fan griond gond this nay, you prmanceat; at aa
# ----
# iter 67100, loss: 49.203496
# ----
#  ill welt,
# And deterity deast of tontrest berabt,
# An aid at me dede swithe, thy carred whe greeblu, trughy dure came fexpencey thy henst gomer; me.
#
# TRAPET:
# Whake shall burre'd' me!
# I'll theredviod;
# Th
# ----
# iter 67200, loss: 49.201298
# ----
#  ng thee defunded, ink.
# Tane thee that encearn me theever yeaththich the maras ssry, be in may suld thing stibe,
# Thou, are wird,
#
# LADY Theved than stiname that my fon lathul. 't me fas you thee; the co
# ----
# iter 67300, loss: 49.178790
# ----
#  ,
# And of that it my mad ant ear, somess my the ilf amy shaw it pell
# In domeess me puit ulite as to theres now lave, the manath writ thy what hithand it comrigp
# Is frield ane farm's raingrecusuet Mwull
# ----
# iter 67400, loss: 49.167368
# ----
#  is agatyed,
# Wiks denalses, man't, our faiceep a jone for my warmy?
#
# ADoNS:
# Latlith Orie were.
#
# HAPTAT:
# Cope gor feam her! wact of fantoutien thet in lave to purerecr! il ishur I' himbled ot my her
# And
# ----
# iter 67500, loss: 49.260979
# ----
#  sy,
# Thesent, ber this forded in trome will come to suck aged the,
#
# LARI VIIZARHEO:
# Andegbive:
# Ind beaded of in and eifuil'd wits.
#
# Furek clent may.
#
# JULINCEO:
# To that to ninf comans, hamlur thy prie e
# ----
# iter 67600, loss: 49.131656
# ----
#  , in; mast!
# Base
# That to the biven sane fearteruflus undaty,
# I say hapry upboules, I there. vir'd fiid a creofouther for to mad: fertim in not me, thy hath, ard, beting be in O condom theathwing,
# O tr
# ----
# iter 67700, loss: 48.993644
# ----
#  heak of in my Lord the joust spIt's hive whear in satkied blage wol'd Joratir witind, thou the athibtlning the giep't mens conso nep!
# There hang's plove not, be umove:
# Thingh sist this his you, on in
# ----
# iter 67800, loss: 49.079394
# ----
#  ow,
# Who chath me upus blainf I pilserseit his ther, stall and and layforter mash man ho will the beann' thel It yenfort of Wast wewis mursely do sullury frart shoullt, werl it, this soo sharrs' Brank
# ----
# iter 67900, loss: 48.980951
# ----
#  men and what no som,
# Bolk.
# Far?
#
# FRINCERY VIIZA:
# Lood'd, thou in bicisenf For true he shore that ghall on thy will pouter he fleaks'd hath we:
# A, thou thead and I slong and herrotes I but of
# Pheagthe:
# ----
# iter 68000, loss: 48.714200
# ----
#  and my the
# I whe cabeevind.
#
# AHEOR ARENR:
# Ruce yeth!
# O try miestalyary:
# Ensith!
#
# WARCERI BULMANGSCARD:
# Fle'st tome, and will in liary, our faruscomanit fors welniog'd, mrant at this say.
#
# YORK:
# Thear;
# ----
# iter 68100, loss: 48.459367
# ----
#  ace the cert tad shirs fits serrice has serelo peis enting he; lore if art then gid
# Dpage shall confe.
# And I mancuet freis.
# Shang.
#
# HENCELA:
# Whou wo kpow lows
# Clay boret sungchul.
# Bet.
#
# PEPRIM:
# Orinls
# ----
# iter 68200, loss: 48.394584
# ----
#  ce.
# Thou it benteld:
#
# NDYTAR CLIO:
# Tham;
# Thou a duimes he, and stead avick ace chom,
# To Vill hozor, in umprenertian on?
# And hasren the cal of shall in thee and come enterme housh ppare ley his lifalr.
# ----
# iter 68300, loss: 48.323901
# ----
#  e lord, to to and thougt.
# So apones!
#
# LENRES:
# Ay il you
# Thtuokseric su?
# Destes.
#
# EONG:
# Yo for faree?
#
# Fir NRICHARD:
# Wherulg cropir
# Whor hink old: sing.
# Of and in ipur.
# And hermast emping frepumes orr'
# ----
# iter 68400, loss: 48.445750
# ----
#  !
#
# LALAN RICORK:
# Enwellove sike sonen show abow hump;
# And sthanc fout wood this ken; Rown, A'd misterf you darengr dack stere!
# And snowcy thy thoon not and sill,
# Hed with there will in a dies? Rown:
# I
# ----
# iter 68500, loss: 48.641052
# ----
#  ow care held fain.
#
# ROKE:
# This have thear to not biders here no lantpand tlike, the preed thas endignd, my with nowan?
# The what hasteaving so hid, his of oug ightrimeexther hey for larn,
# Thee, flitry
# ----
# iter 68600, loss: 48.587562
# ----
#  fith sut promest I'll tirmingard thou the bente.
# Not prou atine dullows!
# Wo nebfrach hizan de enours; ofrurme this pufe srie; sprow the sting hear beath thy houssient, shee!
# Mifliofure? Oren hemes.
#
# L
# ----
# iter 68700, loss: 48.745413
# ----
#  thoul bledit's bean as werak; have to steak alcabfs ofaty to mersy los whaten if thou sake.
#
# CLARDI CORCERLO:
# To of whe, is ther erive mo wisloshie that a swall thut, are be that pomany!
# As thein teac
# ----
# iter 68800, loss: 48.747501
# ----
#   he ah lay ay went.
# They this hear; bear paund, and inreing the himps.
# This foure,
# Flisho?
#
# PlIMK:
# Cotho, have they this hord, hit with kin, will of me, of nend ilyns sinponty I he ingall shath thee h
# ----
# iter 68900, loss: 48.855287
# ----
#  eme to frefem'd in.
#
# LIY:
# No our dees, be twen pife A sand ooll chartered, me hory load whisseck Wecoul with to uppee,
# Mere time ad waute of to wet,
# Conk dures of.
#
# Chick
# IRGIRK:
# Hewe the murst me for
# ----
# iter 69000, loss: 48.875998
# ----
#  Edot mcions.
# 'Thee neel's thein po lone thave shooh!
#
# KING Plimers mond; Cundelt prop of in fith En thee, who to shaYs enaarser saling Rown:
# All his to heap hathinceed a what posince, nand thy cisorI
# ----
# iter 69100, loss: 48.850402
# ----
#  plack flointrefue wiserenberen:
# He deech,' shame.
#
# PFFRAD:
# And boking.
#
# Seifuus.
#
# FARTIS:
# Whint
#
# DUCORGBRARD:
# ''ur think that gitbous!
# boy!
# Thou the to le'tly onk LIns heir,
# Seacls him pate to gor dey
# ----
# iter 69200, loss: 48.795525
# ----
#  ill yourk worpise,
# Edie undernet houst
# Ragio vaist ended arear.
# Soxd?
# Ffe'd by.
# O, head werme, your and pall thour onking kink, waunt's' thou his shathal his gold,
# Whick frarys hembuse timal him shy t
# ----
# iter 69300, loss: 48.587037
# ----
#  --at ugfentled will lik! I cried'd Moris nate;
#
# DUTINo:
# We that nefard I I rickime, the goad hoth bet fale notroak heevinjanded a gule hand unwen aglare his tilly in laygead; there the prother hrard h
# ----
# iter 69400, loss: 48.340172
# ----
#  er:
# And the some whou bathers stand.
#
# HARDY VI: mustlok thike.
#
# ShnAND RICLOUFERINS:
# My?
# En mands a nownood the foorw troad'd stordal make ye fialt low?
#
# GIETiTh YORK:
# Courtuph:
# Plo dewer my thy riden
# ----
# iter 69500, loss: 48.388064
# ----
#  , houle wencle swill;
# I nool,
# And paitheris waa now it weret feret Ruck,
# His mad wo dist, a comand.
#
# HEMMORD:
# To then tast nog the bruch me of proute.
#
# KIENG HENRE LIURBETH:
# Gnon has wice:
# To theinel:
# ----
# iter 69600, loss: 48.198224
# ----
#  not arost Jaom, in il,
# Yed were; I shouth
# granter Arobeld ar conded!
# Comee; heads canger.
#
# CORTHENR I ERENS:
# Thatelfortin, why verege twe mis ad heme,
# Make kirse; that?
# Yord frown hath a dondstayn: So
# ----
# iter 69700, loss: 48.332488
# ----
#  om ne be thingemy.
#
# LARWIA:
# Hamad; So lises; I kerwith me ir afy!
# Where'd streft kill rnquritI fath move to his be then thee chath co me from so ace sood hie call araist a me heteestoning.
#
# PUKECRY:
# T
# ----
# iter 69800, loss: 48.294765
# ----
#  his sothinnt swistad a'd a chere lad ufainn tad in thee our,
# This shonds mance,
# I, and ny'lisusas whil mave, sher me druck mety EFrrot giesdet prevy ther, all sentire hambne
# Shathter's my sposset ligh
# ----
# iter 69900, loss: 48.345689
# ----
#  blainorn hald viliowsrep, trichtley to bromp was for of my of So thour scef, apway on munes your ustling dit the sungord shord with by dott heards stare roffe,
# Were:
# And you, folly cpo.
#
# KARENCE:
# Whal
# ----
# iter 70000, loss: 48.209804
# ----
#  hill they herest seaks Monter like the Riige batastter?
# Ous the san these pemat carsle steen werat for tear that nothee:
# Here frosde?
#
# KING EMEN:
# Dy gumoss
# Thou hioping be aDolow:
# Sitoor to uppand dor
# ----
# iter 70100, loss: 48.202026
# ----
#  rediss, shot seme noble,
# And sceatrevy, brild'd reast:
# Hock that than it frimes,
# Fardal;
# and and srome to dearnch neins then be sot wien.
#
# QUEDY YoLIZARIO:
# When the hulk awaich I houk; of beal to ands
# ----
# iter 70200, loss: 48.011628
# ----
#  l plvy dever comory thy gopher:
# Bulk nabthere wey at mingin, Edeery tonder will moks hoy sur and conqurauth plilest, make's the shaurt,
# Eit whave hordy a con.
#
# GllEt Egame, I him brone.
#
# RONEY PLORDY!
# ----
# iter 70300, loss: 47.595267
# ----
#
# KING ERINCE:
# Thy feath,
# And macn quozeuve did thou I think, aFling for dey'd stam!
# And poll ful wir.
#
# RWARY VO-ETENCE:
# Bof and muck,
# I puesmandruklen thou brong.
#
# WAREDR:
# Ech'd manes of I wod us muad
# ----
# iter 70400, loss: 46.916702
# ----
#  ius a firghsse if be all I conder book, Geakh your you a fover I houres;
# Wil wreever ence:
# Eave I'll loron got wid my stachor at do leckno pors thy conaso?
# Boridiegeads, and me sarsabfienty grys me fo
# ----
# iter 70500, loss: 46.824027
# ----
#  t stade wruth,
# Wo be wites now wak;
# In my be theief gofe yoy the reth are comse.
# Nows.
# Umserenitght, purear hamines a bwald lord domee Ant
# Anst Wear and of tom hand;
# Go wair.
#
# SloGf Your shat trures W
# ----
# iter 70600, loss: 47.121394
# ----
#  e dole'luse to wusperty bettang:
# The if dure my nothing wilenconds mances sues letnese su, I to th cond, I wach, is naril
# Notiling my?
#
# AUMEETER:
# Fow lrods,
# That heppoursis will lord,
# Illy this wit bi
# ----
# iter 70700, loss: 47.349808
# ----
#  th wisughd utwerd that uptard triveen,
# Ham querivy's boind thene,
# Wein stin'me.
#
# SETFr:
# My amise ein, both O, difloungs lemps.
# Et the reek, Seak womod;
# yo Londs!
# Whint, thou wayiru
# ye uftor.
#
# wAXTUT:
#
# ----
# iter 70800, loss: 47.556515
# ----
#  ut, is his gurt Is blame, Ay am yoind,
# They ank drest.
#
# TAAD:
# Tith ad asraingoll, for you; fotk!
# Fou therady leflow seread bum serseremand.
# Frive, sseall my these.
#
# PEWORK:
# A
# Cho.
#
# G LEDY STIA:
# For po
# ----
# iter 70900, loss: 47.426307
# ----
#  esen to heep.
# Baind he the
# I'l hy his', I'dworcengecentry he lesore-Efour.
#
# KING HENRY VIU;
# O with of fardeam?a'd:
# Wrouse to uwnd,
# And stiloan of geping his giss I hintt we like lood then hemen.
#
# KING
# ----
# iter 71000, loss: 47.394690
# ----
#  tsree horess heanmy.
# To like I chaling silby ware thou I vitk that me soull.
#
# RICLEY EDPAS:
# Gor and wher deard scaur be hem,
# Wilt and fell the be whisis morand;
# And whing gelt my I tar teath now me to
# ----
# iter 71100, loss: 47.269124
# ----
#  ime of crach futer's :
# Say gran shaints tho merer bumen,
# And lombore hork.
#
# LEDY CUCIET: Now beemonn!
# Even to entelpr I dimty uponce seare be hie gove memuen,
# Then in thy bilow,
# Whraed store to, in th
# ----
# iter 71200, loss: 47.105185
# ----
#  ofrry's doy,
# Ih.
#
# VARY IV:
# Thy are, maweld jebor cade arone sher.
#
# KICHARD:
# How-
# For ghave somar, himer, shat in to ehtry, EDnceard not your that doum for arer ard so ad whet yempay,
# And have deagr po
# ----
# iter 71300, loss: 47.124380
# ----
#   and lang stull weth all ore my for chanby he cantath our was.
#
# XARTOR:
# And you wir
# WIRCARDO:
# Gnomer, femely:
# So Egay, sprean,
# BUices Cuitin,
# Fto will id take Lork.
#
# PLIRD Ik:
# 'epellady.
#
# KING LAYD.AB
# ----
# iter 71400, loss: 47.167836
# ----
#  hame, I son.
#
# KING ELAFRK:
# Glsmer thatise jukistle to for jay'd whe a king win of tige Wiced ssearsak: yours a kumss?
# Fitting meven tull grietmertith thous Shole uck ourd, of thene how he bake whene's
# ----
# iter 71500, loss: 47.174332
# ----
#  ain thes,
# RId my, virgest as he, beserch to liy the lunss wey not luk bothirifters bromening tha pterses slounny, In for itsent trether,
# Sixcenceecl frar you you a wounds were for choltinge;
# Lesbad be
# ----
# iter 71600, loss: 47.169751
# ----
#   cles goon.
#
# KING:
# Yet cajedent thy thothe in, henWer het,
# And wirl at to lens to year; thancely at in far, to yearns, a ole king rust a that for love his whole too gpeatiowst spires?
#
# RICHETBULA:
# Ori
# ----
# iter 71700, loss: 47.077298
# ----
#  house mode, thatergoo,
#
# KING EPRENCULERy Way.
#
# KING HENRY VI:
# Whex hil me,
# And the flith watane my trure of goproke he your a king mrais youm you of te loinence o caritir, daus,
# 'd ndousy like,
# And fa
# ----
# iter 71800, loss: 47.094387
# ----
#  onden, I lain brourmes all and may.
#
# ADPICARTLY:
#
# VARDCE:
# Watay ard't uthopet no laus all for teuled;
# Hous, well forse me hampee hing'd shalowe.
#
# BOMSARCK:
# Fto ares and me on; he befray!
# Whel
# That wha
# ----
# iter 71900, loss: 46.979163
# ----
#  brorge or the queane be preath Clacref in ligl'deary:
# No and ro hough Endy flomeny kin.
# So carveles now, arest.
# Befuann oflly wey villuckith you witt prean's I distall this dost
# This of I murchter.
#
# K
# ----
# iter 72000, loss: 47.066578
# ----
#   l grok,
# I longed forter hand hanknonf for your atty candok'd that it to nown outn
# Whe gee swack the my ask may!
#
# VORDCICK:
# Eive rebothtmy can greed wound,
# And at there they,
# Andwall whem,
# I haslettoo
# ----
# iter 72100, loss: 47.057043
# ----
#  or's sholt,
# Tray.
# Be's, unto Btomy by the Warbork hows loy of Wort, He picish:
# Ssome, this my but priet our this abeur; time mady, bromt gargy,
# Kakins charr her, thisp his prose,
# Hed goll't frose mory
# ----
# iter 72200, loss: 46.819591
# ----
#  sirge, we heance ong.
#
# WINRECARTI:
# Whant's doured chall thin houl not aroncom wile be stormy.
# Fary and.
#
# EDWARET:
# I prot the vidgears
# Fite is as Sass folge:
#
# WARLOUS:
# Endears Qharushs and his now fres
# ----
# iter 72300, loss: 46.851465
# ----
#  nd that him dake dow thake rige noven this day'ss redoine
# My dy; Yo you men tea tere son, in thou yelf, avel the wall and as cortay;
# poost treer!
#
# YORKTE:
# has beater wis deard will now herver.
# Et prom
# ----
# iter 72400, loss: 46.923112
# ----
#  riefe these maks not menulas How is sir the povoughsrung, ip dariight enes is loted frike
# Bocbord?
#
# WARD:
# Com,
# Tich I mak Buriegr!
# Of lwave Khall the careque cnarespade mane Chould;
# And ting lordid th
# ----
# iter 72500, loss: 47.049417
# ----
#  ens himmir
# Ety sage a doth wht;
# An wyet moke gonst,
# Whe the conter gonchaloings say on Pepreew to me for the quoun untis's; you sagl hnablly my and avandnd
# No slosto unke sunth your it so wo'drens fel
# ----
# iter 72600, loss: 47.209566
# ----
#  Setrow.
#
# GRWICK:
# Why pase, I, heee spore: t, is sowgar hist trowerd's firel,.
#
# HORDY:
# But but me leinen laty beras they day.
#
# FURED:
# Cone. y that.
#
# AULENS?
#
# KING HENMANSE:
# What a shandst me what, the
# ----
# iter 72700, loss: 46.908683
# ----
#  ING;
# SCORDARD:
# T;
# Ooting blough.
#
# GOUEETET:
# 3 thoed hie thea mondiem whut so glorenp!
#
# WARDYCAR:
# Mustin af Bumore dy air thecr spord's quince, sharly hatpers.
# Bus and that at muefes sutter good I cana
# ----
# iter 72800, loss: 46.650504
# ----
#  ice,
# Was thee.
# Forly.
#
# KING HAUES:
# I shose this drack'd, feres.
#
# GLOBXOLIN:
# Greasoud to eaty rey tapen wecand'te to uprinbore vewer,
# Drong oveer,
# Anddodud!
#
# ALUETET:
# Go youl.
#
# Segh bedeed'd.
# Gese of I
# ----
# iter 72900, loss: 46.764637
# ----
#  u lanter, mun dakleazever, this and I sondive love sost bonold thee
# A feardoh me, wosl trowe.
#
# SpWATUMET:
# 3ardse lave you him, enty tlemer havest goverbyly, of the geals interuth thoun Edrs's me low,
# ----
# iter 73000, loss: 46.892530
# ----
#
#
# KING MERCERD:
# Seak tham mancause not astis, me, theo day
# Wheregie by a Whamagh: youbeles.
# Sood With the theip feartathal oweve Corake madhord?
# Highte I dave canlfatt frithelr I hoave aldistoons,
# Or
# ----
# iter 73100, loss: 47.462613
# ----
#  the him iscalld, I wonder.
#
# QUENEBEM:
# There for where jenese sharvles'd hord you the with Kin have wird comeit brave it on, hen I not would that peet havaise Tontire ans suple, war thy oxth; my thatsm
# ----
# iter 73200, loss: 47.762726
# ----
#  will mournby wive rut eref;
#
# QUMERERS:
# Wicatier'S be warming to try thid deghs.
#
# CINUCERLO:
# Your ars as is som;
# I mancuse swerdswuty flooules, emins:
# Burrwien:
# And ourst man. Heingerm the cuss his our
# ----
# iter 73300, loss: 47.939455
# ----
#  s tacke,
# Noo luppernay's silesongen yoo, a do, my truing,
# This had hee thente's not spot, grot, epondene soode, and Eat to mese on to prake,seal a to gloniyet's by gone I'll, have alit slanours, faWix
# ----
# iter 73400, loss: 48.184743
# ----
#  nes nor ther, were.
#
# Glous
# Asding Cpay mant.
#
# YORWARD IV:
# As ho liut:
# Oo men'd brould you Where of Lovemples come illlls; tham in lance deyor, gane stoonin I himel's the sike hand
# And and
# And grare my
# ----
# iter 73500, loss: 48.337816
# ----
#  hebill you thee kide
# Yoy.
#
# QUEET:
# Be
# The wide,
# Aite am be thous on.
#
# LOUTETR:
# Muck homesiged.
# Shas tile in allo,- pender, his but-'Tuth'
# With Ear call shill.
#
# HENMPHTY:
# Wel angor.
#
# LEORTET:
# Um, lens t
# ----
# iter 73600, loss: 48.569305
# ----
#  y,
# Bup will in'd mire she and for conthirgie viok Waimaty; a furss haa dut exemy reave gain!
# Boul, I whis awr deat shith'd this suke my love now nothist we take lones?
# Betin,
# Sith my to buck
# Whom and
# ----
# iter 73700, loss: 48.699283
# ----
#  k me wompinss Wall with him proke west fith pengignare abawn
# End forsunt.
#
# LEONTEBES:
# But, more and intrigetile.
#
# GLONEES:
# Whow sulue's the bes'n veed hus,
# Gike ould, miceann.
#
# MEOSGBRO:
# Ond
# That im t
# ----
# iter 73800, loss: 48.744023
# ----
#   thous doy thaik
# Nour stid
# Yo: me slokes mangar this and infare, if joll have comel the sin's mes lich sly ackn; wefoldy all of wich veods a fured queevere ened a santy now
# I Ho as ast not his shuth c
# ----
# iter 73900, loss: 48.709737
# ----
#  poondswas whe is uthare have warisped.
#
# PLALIN:
# Iny y.
#
# LALEDREMS:
# Py prof unour
# Int mers as candse, there blave in.
# Tilem will wellago, lisccemoll phonges,
# Yelrenken hes:
# Thel undeve? and to thou the
# ----
# iter 74000, loss: 48.668656
# ----
#  e my our'd-shonese blejy of lasch in the dicchal all the a pardsened on hered the I loth am I of all that willo yay,
# Then, no'
# yhed you for my his ryotry pawith me bacherss to moo dutpemty
# Thearst, do
# ----
# iter 74100, loss: 48.737219
# ----
#  s all''s
# Your
# Fary me quein is your from spake I dagligh me in men's.
#
# LELTENES:
# Hese tore to prosfoosters youe, iver:
# I quevick
# Marsar, beas noep and farty in till foun; me hard hitier now age goosun
# ----
# iter 74200, loss: 48.711993
# ----
#  d eingry,
# The feill potineon, sonour shight hind allichtt to decery, to your dor: youd; hime, this dite conder your. Hovespur, 'terpelt,
# Thy a shald tame the aref and caver: virs.
# Clopled;
# What he the
# ----
# iter 74300, loss: 48.771884
# ----
#  this werell' prray wond quernaak,
# Sight-wont tee; stidorrth's the shink prome ttall or tiels radfer'd love saye.
#
# MERIN IN Fick my sprechefuedevy
# AQwinco this s here I deccinn!
# Your thiss dortond's ex
# ----
# iter 74400, loss: 48.960157
# ----
#  nsets aa yer contidiond I solver'd impalvous of till' yeed lit's knot's a out 'Lresby' where
# He?
#
# ETEVLATS:
# O, prost is to her hourch and and I'ly gour to mremengef's' thy aring Tost asl.
#
# GLOUTIS:
# Pr
# ----
# iter 74500, loss: 49.005495
# ----
#   are dowen cuet he the the prood hengor Lad
# Loydevirs;
# Os your my this by of Coreale verey tood, pace:
# I here hen? 'Louca; prusffore to steaniud Twares
# Oll oft
# Whand, enged,
# Loth hoved, as wow hord hi
# ----
# iter 74600, loss: 48.767125
# ----
#  nd bleet?
# The cover broned mare swather wad Come I ourly; offeld to the panvoud truin prosmad: be thom hationth thou for werst me
# The grouge, sforts, we to be the gals dile nor he me'ly eren's that wi
# ----
# iter 74700, loss: 48.703665
# ----
#  .
#
# DAspirt
# Or yen and about his Is my toulsegl,
# I shoull.
# That lierself radister to shithhe? Sire tho le heme, is to erving warde?
#
# PALINTIS:
# My luns for unteriughter, one shall flase
# Twance; war desa
# ----
# iter 74800, loss: 48.670969
# ----
#  Forwore kist. Lyo deenled-To not iss gadter and stimerss.
# Should, bath cood she come. Why, spaicht lood.
#
# Thies appealipe avileech'd, to have will and on, ithy, as wese beace's day
# Not? grente thingt
# ----
# iter 74900, loss: 48.895290
# ----
#  ll sonale it
# God that thing the kie-yoo now by thiss, Entort:
# Hy dath, wencho his youl loke
# Mioh dicce
# lay:
# If teles;
#
# CLEXIELI I LEOR:
# I in llest oft.
#
# PEONTENLE:
# In I cencom'm, ollunce forling;'s ca
# ----
# iter 75000, loss: 48.806530
# ----
#  at fiter, astank to the oft:
# The lethistenone sow, hit rild:
# Gours
# The thirg the frowide
# Dy bur to aspereswingtungs;
# Ass itt! If sholl nowst ne?
#
# LeckBULAR:
# Putsnided of creece-furby ago farss.
# Tyoulf
# ----
# iter 75100, loss: 48.771140
# ----
#  thals ere't;
# Iy youp priss sozest sshow hand. siderstars?
#
# QUHENTEN:
# Gikend befole?
#
# LAULINII LEIN BORES:
# Nom prict.
#
# See'aiktide oof Henguefling: youd, here.
# 'nis seriost.
#
# Perongent it and heathizo?
# ----
# iter 75200, loss: 48.969851
# ----
#   gear that shee for sood chimge ave not
# I'll ipath!
# Goa to to of me to wice that lone I dengolin
# By a fraw! no in I king el that le pors at up lake Ore't Yo, coods I dnay why makat beat
# an blade the p
# ----
# iter 75300, loss: 48.902501
# ----
#  me
# weatht ought!
# Bugh the pele: nith faitho:
# You rebole
# Yot:
# I ringe
# The avathoo hash in bo-this,
# Heen in en,
# His bee,
# Shat their prave,
# By be'd it not the is is tirte, arys?
# The so men:
# The, quoctang
# ----
# iter 75400, loss: 49.146824
# ----
#  kels; the no have hamch;
# No nownt't mowerst, I sin'
# Mawn! A'd then:
# Whet
# I minge
# I child quetherwers fal as, bron:
# I have tot: unwid the bistonederd hives andige'd mobeer, weeds.
#
# Cadded bo shamesue s
# ----
# iter 75500, loss: 49.466738
# ----
#   I in ane agelve dewing sontuss save I dent
# To the day that do'd:
# A thim lood har sh't that wake ming, way him boather, jaint's, a farewer
# Nain conote sheagl for gasinged twere:
# Of fame!
# Ih! veags gal
# ----
# iter 75600, loss: 49.483406
# ----
#   bromeed;
# Than, whos afloul rectenjulfood
# To, fotindst sevee heam, ect there:
# This
# of, rethennellothy, haswele that make, sseagn and dackne; hemce! lownles prove futrings.
#
# PONOED:
# In grend:
# They my s
# ----
# iter 75700, loss: 49.514070
# ----
#  e mave I fawers? int the los
# jus I am is lever then mishertpoft the pring
# Prate of this shand, 'streds bo thee angancound thous'd den our may oof me this wack when!
# he wiseed closter-my food I it sali
# ----
# iter 75800, loss: 49.787758
# ----
#
# Flublale hatwicns ar wost of frints frear! thearg, conser: not il mand! I preeble ot shatry oul youe's this her a and san
# Agent.
#
# CAUCES:
# I bith put.
#
# Sergth lenn it I das lound chousalious!
#
# AUFEUT:
# ----
# iter 75900, loss: 49.834464
# ----
#  eprly wird you, of do, sons, of Ewod us my treing, ow. Hor I paiters
# you hir't: hand thoul.
# Bwak. and the
# put horice ip, ow, he I I thamp, 'o
# kneve urjathay Parstaly, are fourd; weely verout the; an m
# ----
# iter 76000, loss: 49.890915
# ----
#  g tan,
# Fo sougl-
# Fured's, me be,
# To our sheden unding:
# And nones's; bathese! now the nefinige
#
# PolTIUS- there the lroving whougr a desherde aWobe
# Aren, and to my for hins golin't love brange. To fell.
# ----
# iter 76100, loss: 49.712881
# ----
#  Cavencer nop hast brouf my appemuch hay you surr: for mave Lonfors ant Werle,
# Ditk.
# Nobes on Prosen whitred thy ow; my parne stilies, will dood;
# Muscunt umpave:
# Word this shartor slem of whang
# A to, h
# ----
# iter 76200, loss: 49.702501
# ----
#  er's osl, agorars feands! lodos profle slime hinks, here yeulld.
# You abatuen's, that imselylens
# I and thise:
#
# For the;
# All not rockat nore, shathed slong dake
# Dichimgal nolany!
# Shech mear thee, of tha
# ----
# iter 76300, loss: 49.896629
# ----
#  idest of upy
# AD' thoughart sing. Led truee, thee fark, outt buts freencu fastoon moum Doof.
#
# SelCHARGES:
# Thick Thou ey; the uredans balsich and hids nand harkany: math is deaceysel vougho
# good, rimesr
# ----
# iter 76400, loss: 49.871181
# ----
#  k. youes. you warick? ut clathor?
#
# PERDeMcER:
# Thoup
# Sret that
# Clifjue, don. Edanres, gappurk? wakin with macks:
# And weam, taser, a dopfled: that
# And sware spather Earcoant this totrincess.
# Far in be s
# ----
# iter 76500, loss: 49.784940
# ----
#  ld
# Now; partelr and but but lyath kign
# Fribed-sin tul
# I br: in hemedim? Mutele worm Pornes?
#
# PLORDICK:
# My hang, mes yet'ss dosin's dosecofary desterso, tirt; are, what thon at for the share;
# UoWe for,
# ----
# iter 76600, loss: 49.467239
# ----
#  stings you that valf thy at looke to on
# That to do is this wind bowilne at hersary her fars me fareews.
#
# HOUTESTIN:
# The, in. Has mens lenghtest mur.
# Oy mike
# pur that seakine lust:
# Whris nos ecterss to
# ----
# iter 76700, loss: 49.343835
# ----
#   ave king and have gar
# all, but ushert. nougho shay
# Go, love's
# You kwers: bo is uploutby, not ther,
# These I't afrank
# Thing, oarlany?
#
# Sepght of crithe: patwake,
# If wher way suver betuthe taks;
# Tho wal
# ----
# iter 76800, loss: 49.202629
# ----
#   wird;
# What
# Thee hach Vils hast as sprit, may
# Thee stith fatho rep's peverver at
# I burond ugke. My As of of loty
# I bet if it that hark! tels:
# I your fark:
# His good quight btorod has
# O jure, wrutildod
#
# ----
# iter 76900, loss: 48.954313
# ----
#  g,
# Me amd far shall pate
# Beco of refally, will preinot mides, oftin, I pronging your my
# And seed ix you, with harf not as weld the charth bightuventting on him eanttsh engerdwant: wale?
#
# LEONTELOM:
# My
# ----
# iter 77000, loss: 48.895306
# ----
#   contand! and Mice hapan be so kare veing youp me wheay nown; you trowen your or enter, I wad fFom so, modile of fither's the now you kies;
# For aocoo the wald: but elke, werd forth his pues, best,
# Cll
# ----
# iter 77100, loss: 48.708249
# ----
#  S:
# Nor it,
# Thee
# For seak,
# Thes.
# Yeue sasch me thed
# UGle-kmo king, who here perseen. Hense, fath ato's sose thee to checingur love on. Bue porthen
# And ster alive yay of your andin whire here ald
# dus, y
# ----
# iter 77200, loss: 48.529101
# ----
#  ce preangor vinnt! ye'testante, this the yout a cach he
# The caull, wheie our yety, tho hereswert. now stight miflanded youn. and be
# I'll serser knosann than thise chey;
# Shoud-shant sen,
#
# AUEO LOLE:
# An
# ----
# iter 77300, loss: 48.421081
# ----
#  het chave-ferise
# gord, fars:
# Mape intecrens: fof yes me. wher, phall my formes sar thing, hough ay blepencis? tuth op ay till hive ind;
# What you
# he serge tor al them grawlutherduends
# I the servild sor
# ----
# iter 77400, loss: 48.325919
# ----
#  in
# or you pissows noy crent,
# The renden souself mort; and os: groat is mare shalles and lay goom, shanceavertholl quead you des: I kookss fromele uhoo-dlstiinserslyord themune sord wo fill werr the ke
# ----
# iter 77500, loss: 48.349111
# ----
#  all pwost! what neperwole priott
# God me to is to aploor?
#
# CUFIMLADS:
# She moyest with Now stercowates.
# Chisl a you wae toa sortlec
# I monquest that ssowp it
# ko kneets
# Whore bunt
# Now cackishde
# For my bub
# ----
# iter 77600, loss: 48.329448
# ----
#   as my this beary eraneds me; Thenest So, I and for camsed.
#
# ARIS ID:
# Your'n
# Lissersenvely whenen.
# FAokter
# Sise, baten.
#
# BAONSENCE:
# You;--feart chelithe, his thim hounts
# I'l know, mile;
# The wertutite,
# ----
# iter 77700, loss: 48.344316
# ----
#  our bur wholle is drith the kgorrelf,
# If cling to hir witmay a veenes;
# Will not So apwizen:
# My abravills bedore privygath proved my all spomt.
#
# PMORD IVI: to doil? Qor owerss, mishchan the-s aD mets b
# ----
# iter 77800, loss: 48.263086
# ----
#  ou it a musher:
# Theness and my ougture gordsest to danty sore,
# Sepaldriven bryirdstion's wemuch then and me son in, thou hen-fucounteldinededs, which beell mance me mon reast?
# Her oll wertly
# ents, the
# ----
# iter 77900, loss: 48.334832
# ----
#  nd have it arvead thas preetacroundning her of
# Anwank, if ther:
#
# DUROLIZAN:
# No sost of in and mues the a'd wew carses striens yous
# Cumont'd in donderdepe, le mike not sind your shiist not tirs n'arrte
# ----
# iter 78000, loss: 48.462116
# ----
#  o hore'd sit:
# I ballin, hearm wht the reall het.
#
# LEONTES:
# That puring priesuercear that serthended sirps and by thy lave.
#
# Set be's enes: tore
# ey plomerss, to not ot: wrut naven, deat:
# Whick the hand
# ----
# iter 78100, loss: 48.472377
# ----
#  igg; of you hancest
# Conester is thou thow what ace his and senill rapan ea; if in heartaty thick dear; mathning Is fovers yere where, a farwavey's ontirus hagh?'
#
# QUELO:
# You,
# I, kiest as father conor
# ----
# iter 78200, loss: 48.095287
